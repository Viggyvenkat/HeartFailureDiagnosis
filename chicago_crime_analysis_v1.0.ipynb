# %% [markdown]
# # Chicago Crime Analysis
# ### Authors - Vignesh Venkat, Adarsh Narayanan, Arush Verma
# ### Version 1.0

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn as sk

# %%
crimes_df = pd.read_csv('Crimes_-_2001_to_Present.csv')

# %%
crimes_df
# Out:
#                ID Case Number                    Date                  Block  \
# 0        10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST
# 1        10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE
# 2        11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE
# 3        10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE
# 4        10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE
# ...           ...         ...                     ...                    ...
# 7663784  12847575    JF420478  09/01/2022 05:00:00 AM        005XX W SURF ST
# 7663785  12847801    JF420319  07/08/2022 12:00:00 AM    114XX S PRAIRIE AVE
# 7663786  12847324    JF420102  09/27/2022 11:00:00 AM        023XX E 70TH ST
# 7663787  12847570    JF420427  09/03/2022 10:25:00 AM     052XX W CARMEN AVE
# 7663788  12840464    JF411839  09/26/2022 07:20:00 PM      0000X N MASON AVE
#
# ...

# %% [markdown]
# crimes_df_2012 =
